# %% [markdown]
# <a href="https://colab.research.google.com/github/ussalbt/Assignment/blob/main/Assignment_2_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %%
kill = pd.read_csv('/content/sample_data/PoliceKillingsUS (3).csv', encoding="windows-1252")

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill.shape
# Out:
# (2535, 14)

# %%
# Out:
# (2535, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head()
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %%
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="gender",y="age",data=kill,hue="manner_of_death");

# %%
# with seaborn

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x="gender",y="age",data=kill,hue="manner_of_death");

# %%
# with seaborn

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
city_freq=kill.city.value_counts().head(12)
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
city_freq = 
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
city_index=city_freq.index
city_index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Oklahoma City', 'Tucson'],
#       dtype='object')

# %%
city_count=city_freq.values
city_count
# Out:
# array([39, 31, 27, 25, 21, 20, 19, 18, 18, 15, 14, 14])

# %%
plt.figure(figsize = (8,5))
sns.barplot(x = city_index, y = city_count, data = kill)
plt.title('Most dangerous cities', color = 'blue', fontsize=16)
plt.xticks(rotation=45);

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax = 
ax.
ax.

# %%
plt.figure(figsize = (8,5))
sns.countplot( x = 'city', order = city_index,data=kill);
plt.title("Most dangerous cities", color = "blue", fontsize=16)
plt.xticks(rotation = 45);

# %%
# with seaborn countplot
fig, ax =plt.subplots(figsize=(8,5))
sns.
ax.
ax.

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
state_freq= kill.state.value_counts().head(20)
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
state_freq = 
state_freq
# Out:
# CA    424
# TX    225
# FL    154
# AZ    118
# OH     79
# OK     78
# CO     74
# GA     70
# NC     69
# MO     64
# IL     62
# WA     62
# TN     59
# LA     57
# PA     51
# NM     51
# AL     50
# VA     47
# NY     45
# SC     44
# Name: state, dtype: int64

# %%
state_index=state_freq.index
state_index
# Out:
# Index(['CA', 'TX', 'FL', 'AZ', 'OH', 'OK', 'CO', 'GA', 'NC', 'MO', 'IL', 'WA',
#        'TN', 'LA', 'PA', 'NM', 'AL', 'VA', 'NY', 'SC'],
#       dtype='object')

# %%
state_count=state_freq.values
state_count
# Out:
# array([424, 225, 154, 118,  79,  78,  74,  70,  69,  64,  62,  62,  59,
#         57,  51,  51,  50,  47,  45,  44])

# %%
plt.figure(figsize = (8,6))
sns.barplot(x = state_index,y=state_count, data = kill)
plt.title('Most dangerous states', color = 'blue', fontsize=16)
plt.xticks(rotation=45)
plt.show()

# %%
# with seaborn barplot
fig, ax =plt.subplots(figsize=(8,5))
ax.set_title("Most Dangerous states")
ax.bar(x,y)
ax.y_label("state_freq")

# %%
plt.figure(figsize = (8,6))
sns.countplot(x = 'state', order = state_freq.index, data = kill)
plt.title('Most dangerous states', color = 'blue', fontsize=16)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
kill.sample()
# Out:
#         id   name      date  ... threat_level   flee  body_camera
# 2091  2328  TK TK  12/02/17  ...        other  Other        False
#
# [1 rows x 14 columns]

# %%
illness= kill.signs_of_mental_illness.value_counts()
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
illness = 
illness
# Out:
# False    1902
# True      633
# Name: signs_of_mental_illness, dtype: int64

# %%
sns.countplot(x="signs_of_mental_illness",order=kill.signs_of_mental_illness.value_counts().index,data=kill);

# %%
# with seaborn

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threads_freq= kill.threat_level.value_counts()
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
threads_freq = 
threads_freq
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
sns.countplot(x="threat_level",order=kill.threat_level.value_counts().index,data=kill);

# %%
# with seaborn

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee_freq =kill.flee.value_counts()
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
flee_freq = 
flee_freq
# Out:
# Not fleeing    1695
# Car             385
# Foot            294
# Other            96
# Name: flee, dtype: int64

# %%
sns.countplot(x="flee",order=kill.flee.value_counts().index,data=kill);

# %%
# with seaborn
